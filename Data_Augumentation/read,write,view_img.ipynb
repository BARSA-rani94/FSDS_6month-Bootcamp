# %%
import cv2

# %%
import numpy as np

# %%
input=cv2.imread(r"C:\Users\HP\OneDrive\Desktop\training\Happy_faces\2.jpeg")

# %%
input
# Out:
# array([[[ 31,  27,  38],
#         [ 32,  28,  39],
#         [ 32,  28,  39],
#         ...,
#         [ 46,  73, 159],
#         [ 49,  76, 157],
#         [ 49,  76, 156]],
#
#        [[ 32,  29,  38],
#         [ 32,  29,  38],
#         [ 32,  29,  38],
#         ...,
#         [ 47,  72, 158],
#         [ 47,  74, 155],
#         [ 48,  75, 155]],
#
#        [[ 34,  31,  33],
#         [ 34,  31,  33],
#         [ 35,  32,  34],
#         ...,
#         [ 47,  69, 157],
#         [ 47,  71, 155],
#         [ 48,  72, 154]],
#
#        ...,
#
#        [[ 20, 111, 210],
#         [ 21, 104, 196],
#         [ 32,  96, 174],
#         ...,
#         [ 43, 180, 242],
#         [ 35, 178, 239],
#         [ 22, 168, 228]],
#
#        [[ 21, 114, 213],
#         [ 23, 106, 198],
#         [ 31,  95, 173],
#         ...,
#         [ 46, 182, 241],
#         [ 40, 180, 239],
#         [ 27, 170, 228]],
#
#        [[ 23, 116, 215],
#         [ 25, 108, 200],
#         [ 29,  95, 173],
#         ...,
#         [ 48, 184, 243],
#         [ 45, 184, 241],
#         [ 32, 173, 230]]], shape=(300, 168, 3), dtype=uint8)

# %%
cv2.imshow('2',input)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print('Height:',int(input.shape[0]),'pixels')
print('Width:',int(input.shape[1]),'pixels')
# Out:
# Height: 300 pixels
# Width: 168 pixels
